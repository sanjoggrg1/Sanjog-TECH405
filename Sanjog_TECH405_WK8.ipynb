# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjoggrg1/Sanjog-TECH405/blob/main/Sanjog_TECH405_WK8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import libraries
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense

# %%
# Step 2: Load dataset
vocab_size = 10000  # use top 10k words

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)

print("Training samples:", len(X_train))
print("Testing samples:", len(X_test))
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training samples: 25000
# Testing samples: 25000

# %%
# Step 3: Pad sequences (make all reviews same length)
max_length = 200

X_train = pad_sequences(X_train, maxlen=max_length)
X_test = pad_sequences(X_test, maxlen=max_length)

# %%
# Step 4: Build Bi-LSTM model
model = Sequential()

# Embedding layer (convert word index → dense vector)
model.add(Embedding(input_dim=vocab_size, output_dim=128, input_length=max_length))

# Bidirectional LSTM
model.add(Bidirectional(LSTM(64)))

# Output layer
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# Step 5: Compile model
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Step 6: Train model
history = model.fit(
    X_train, y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 158s 489ms/step - accuracy: 0.7880 - loss: 0.4584 - val_accuracy: 0.8292 - val_loss: 0.3875
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 212s 521ms/step - accuracy: 0.8915 - loss: 0.2745 - val_accuracy: 0.8676 - val_loss: 0.3143
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 193s 494ms/step - accuracy: 0.9261 - loss: 0.1912 - val_accuracy: 0.8648 - val_loss: 0.3210
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 209s 517ms/step - accuracy: 0.9499 - loss: 0.1407 - val_accuracy: 0.8698 - val_loss: 0.4174
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 153s 489ms/step - accuracy: 0.9629 - loss: 0.1061 - val_accuracy: 0.8520 - val_loss: 0.4986

# %%
# Step 7: Evaluate
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 61ms/step - accuracy: 0.8472 - loss: 0.5124
# Test Accuracy: 0.8472399711608887

# %%
# Add Dropout (reduce overfitting)

from tensorflow.keras.layers import Dropout

model.add(Bidirectional(LSTM(64, return_sequences=False)))
model.add(Dropout(0.5))

# %%
# Use deeper Bi-LSTM
model.add(Bidirectional(LSTM(64, return_sequences=True)))
model.add(Bidirectional(LSTM(32)))

# %%
# Increase max_length
max_length = 300

# %%
# Testing with Your Own Sentence
from tensorflow.keras.preprocessing.text import Tokenizer

word_index = imdb.get_word_index()

def encode_review(text):
    tokens = [word_index.get(word, 2) for word in text.lower().split()]
    return pad_sequences([tokens], maxlen=max_length)

test_review = "This movie was absolutely amazing"
encoded = encode_review(test_review)

prediction = model.predict(encoded)
print("Positive" if prediction > 0.5 else "Negative")

# %%
# Load via Tensorflow Datasets
import tensorflow_datasets as tfds

ds, info = tfds.load(
    "imdb_reviews",
    split=['train', 'test'],
    as_supervised=True,
    with_info=True
)
# 50,000 reviews, 0=negative, 1=positive

# %%
# Model cofiguration
model = sequential
Embedding(VOCAB, 100,
weights =[embed_matrix],
trainable=False),
Bidirectional(LSTM(128,
dropout=0.3
recurrent_droppout=0.3))),
Dense(64, activation='relu'),
Dropout(0.5),
Dense(1, activation='sigmoid')

# %%
# Hyper Parameters
# Training configuration
vocab_size = 10_000
MAX_LENGTH = 200 #tokens
EMBED_DIM = 100 #Glove-100d
LSTM_UNITS = 128
BATCH_SIZE = 64
EPOCHS = 10
OPTIMIZER = 'adam'
LOSS = 'binary_crossentropy'
# Early stopping: patience=3

# %%
# Classifying Labels
# Run inference on a review
review = "This film was absolutely" "brilliant and moving"
seq = tokenizer.texts_to_sequences(
[review])
padded = pad_sequences(seq, maxlen=Max_LENGTH)
prob = model.predict(padded)[0][0]
label = "Positive" if prob>0.5
else "Negative"
Sentiment: Positive (0.94)
